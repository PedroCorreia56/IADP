# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(123456)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2019", periods=1000))
ts.head(50)
# Out:
# 2019-01-01    0.469112
# 2019-01-02   -0.282863
# 2019-01-03   -1.509059
# 2019-01-04   -1.135632
# 2019-01-05    1.212112
# 2019-01-06   -0.173215
# 2019-01-07    0.119209
# 2019-01-08   -1.044236
# 2019-01-09   -0.861849
# 2019-01-10   -2.104569
# 2019-01-11   -0.494929
# 2019-01-12    1.071804
# 2019-01-13    0.721555
# 2019-01-14   -0.706771
# 2019-01-15   -1.039575
# 2019-01-16    0.271860
# 2019-01-17   -0.424972
# 2019-01-18    0.567020
# 2019-01-19    0.276232
# 2019-01-20   -1.087401
# 2019-01-21   -0.673690
# 2019-01-22    0.113648
# 2019-01-23   -1.478427
# 2019-01-24    0.524988
# 2019-01-25    0.404705
# 2019-01-26    0.577046
# 2019-01-27   -1.715002
# 2019-01-28   -1.039268
# 2019-01-29   -0.370647
# 2019-01-30   -1.157892
# 2019-01-31   -1.344312
# 2019-02-01    0.844885
# 2019-02-02    1.075770
# 2019-02-03   -0.109050
# 2019-02-04    1.643563
# 2019-02-05   -1.469388
# 2019-02-06    0.357021
# 2019-02-07   -0.674600
# 2019-02-08   -1.776904
# 2019-02-09   -0.968914
# 2019-02-10   -1.294524
# 2019-02-11    0.413738
# 2019-02-12    0.276662
# 2019-02-13   -0.472035
# 2019-02-14   -0.013960
# 2019-02-15   -0.362543
# 2019-02-16   -0.006154
# 2019-02-17   -0.923061
# 2019-02-18    0.895717
# 2019-02-19    0.805244
# Freq: D, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df.head(3)
# Out:
#                    A         B         C         D
# 2019-01-01 -0.218470 -0.061645 -0.723780  0.551225
# 2019-01-02 -0.497767  0.837519  1.103245 -1.118384
# 2019-01-03 -0.542980 -0.994002  1.508742 -0.328697

# %%
df = df.cumsum()
plt.figure()
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df))))
df3.tail(3)
# Out:
#              B         C    A
# 997 -27.398674 -2.735528  997
# 998 -29.589450 -2.312671  998
# 999 -29.733052 -3.633835  999

# %%
df3.plot(x="A", y="B")

# %%
df.iloc[5].plot(kind="bar")
df.iloc[5].plot.bar()

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2.head(3)
# Out:
#           a         b         c         d
# 0  0.776756  0.303773  0.428600  0.070400
# 1  0.249213  0.973558  0.404596  0.777473
# 2  0.644560  0.022563  0.444410  0.804606

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)
df4.head(3)
# Out:
#           a         b         c
# 0  1.717808  1.600283 -0.854723
# 1  0.099041 -0.605731 -0.691854
# 2  2.180217 -0.561047 -2.043530

# %%
df4.plot.hist(alpha=0.5);

# %%
df = pd.DataFrame(
    np.random.rand(10, 5), 
    columns=["A", "B", "C", "D", "E"])
df.head(3)
# Out:
#           A         B         C         D         E
# 0  0.177332  0.580773  0.296386  0.077946  0.190391
# 1  0.157114  0.647679  0.079399  0.711080  0.356732
# 2  0.489527  0.299715  0.650378  0.768944  0.857699

# %%
df.plot.box();

# %%
df = pd.DataFrame(
    np.random.rand(10, 4),
    columns=["a", "b", "c", "d"])
df.head(3)
# Out:
#           a         b         c         d
# 0  0.650358  0.142018  0.859387  0.941305
# 1  0.328915  0.396671  0.853521  0.058256
# 2  0.863381  0.767262  0.471649  0.139792

# %%
df.plot.area();

# %%
df = pd.DataFrame(
    np.random.rand(50, 4),
    columns=["a", "b", "c", "d"])
df["species"] = pd.Categorical(
    ["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10
)
df.head(50)
# Out:
#            a         b         c         d     species
# 0   0.155123  0.262281  0.496580  0.814731      setosa
# 1   0.663092  0.016283  0.777753  0.693351      setosa
# 2   0.850878  0.066799  0.192226  0.784649      setosa
# 3   0.090693  0.529175  0.543386  0.024546      setosa
# 4   0.584868  0.710948  0.299030  0.681708      setosa
# 5   0.173686  0.199530  0.941276  0.352342      setosa
# 6   0.760892  0.081325  0.787057  0.371940      setosa
# 7   0.854988  0.568744  0.982264  0.964133      setosa
# 8   0.617888  0.772792  0.320561  0.710854      setosa
# 9   0.104574  0.258995  0.565302  0.301441      setosa
# 10  0.315673  0.534177  0.166999  0.212350      setosa
# 11  0.526799  0.648745  0.325732  0.987608      setosa
# 12  0.238909  0.546402  0.480096  0.004521      setosa
# 13  0.280791  0.550989  0.236173  0.187050      setosa
# 14  0.821721  0.577091  0.754517  0.297247      setosa
# 15  0.700444  0.638497  0.835693  0.718455      setosa
# 16  0.690679  0.438132  0.830396  0.780659      setosa
# 17  0.277769  0.415793  0.539153  0.434645      setosa
# 18  0.384729  0.073565  0.793775  0.836313      setosa
# 19  0.725325  0.492907  0.996394  0.784399      setosa
# 20  0.835741  0.780492  0.265555  0.616599  versicolor
# 21  0.364011  0.266299  0.462475  0.462738  versicolor
# 22  0.224949  0.818857  0.660795  0.296310  versicolor
# 23  0.686804  0.538110  0.855838  0.199749  versicolor
# 24  0.372189  0.697004  0.443045  0.092116  versicolor
# 25  0.692399  0.319477  0.071731  0.613999  versicolor
# 26  0.844084  0.951339  0.594742  0.275041  versicolor
# 27  0.913499  0.189570  0.954294  0.295491  versicolor
# 28  0.657188  0.790804  0.308856  0.723770  versicolor
# 29  0.871189  0.128234  0.788834  0.989595  versicolor
# 30  0.593566  0.647628  0.246976  0.121807  versicolor
# 31  0.992550  0.704793  0.639173  0.978454  versicolor
# 32  0.132201  0.357879  0.539543  0.696932  versicolor
# 33  0.361107  0.595021  0.947764  0.088807  versicolor
# 34  0.418403  0.592201  0.862860  0.001119  versicolor
# 35  0.622189  0.371814  0.629233  0.845732  versicolor
# 36  0.113450  0.371000  0.045102  0.778179  versicolor
# 37  0.630501  0.357832  0.661881  0.336432  versicolor
# 38  0.196281  0.185424  0.518482  0.919355  versicolor
# 39  0.885562  0.227598  0.611881  0.832651  versicolor
# 40  0.180834  0.480708  0.181548  0.783415   virginica
# 41  0.263231  0.167415  0.883076  0.243732   virginica
# 42  0.789599  0.188024  0.334495  0.708129   virginica
# 43  0.845012  0.091517  0.547889  0.634779   virginica
# 44  0.775513  0.128097  0.757420  0.620315   virginica
# 45  0.716617  0.739462  0.108423  0.073774   virginica
# 46  0.636031  0.519648  0.614644  0.983890   virginica
# 47  0.009556  0.646707  0.134964  0.990165   virginica
# 48  0.278020  0.094559  0.670652  0.372044   virginica
# 49  0.967419  0.121648  0.816400  0.773483   virginica

# %%
df.plot.scatter(x="a", y="b");

# %%
df = pd.DataFrame(
    np.random.randn(1000, 2),
    columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df.head(3)
# Out:
#           a         b
# 0 -0.477601 -0.692893
# 1  1.360552  0.985217
# 2  0.713865  3.025486

# %%
df.plot.hexbin(x="a", y="b", gridsize=25);

# %%
series = pd.Series(
    3 * np.random.rand(4),
    index=["a", "b", "c", "d"], name="series")
series.head(3)
# Out:
# a    0.408321
# b    1.254653
# c    1.757288
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6));

# %%
ser = pd.Series(np.random.randn(1000))
ser.head(3)
# Out:
# 0    1.375064
# 1   -0.268824
# 2   -1.503032
# dtype: float64

# %%
ser.plot.kde();

# %%
price = pd.Series(
    np.random.randn(150).cumsum(),
    index=pd.date_range("2000-1-1", periods=150, freq="B"),
)
ma = price.rolling(20).mean()
mstd = price.rolling(20).std()
plt.figure();
plt.plot(price.index, price, "k");
plt.plot(ma.index, ma, "b");
plt.fill_between(
    mstd.index, ma - 2 * mstd, ma + 2 * mstd, color="b", alpha=0.2);
